# %%
# Import libraries
# GoogleNews Documentation : https://pypi.org/project/gnews/
from gnews import GNews
import pandas as pd
import nltk  # NLP library
from tqdm.auto import tqdm
import warnings

warnings.filterwarnings('ignore')

# %%
# This tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alfonso/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Initializing
googlenews = GNews()

# %%
# Settings
googlenews = GNews(language='en',start_date=(2023, 8, 1), end_date=(2023, 8, 2))

# %%
# Search 
searchednews = googlenews.get_news('Ukraine')
print(f"Articles found:", len(searchednews))
# Out:
# Articles found: 51

# %%
# Results
print(searchednews[1])
# Out:
# {'title': 'The Crimean Peninsula is both a playground and a battleground, coveted by Ukraine and Russia - The Associated Press', 'description': 'The Crimean Peninsula is both a playground and a battleground, coveted by Ukraine and Russia  The Associated Press', 'published date': 'Tue, 01 Aug 2023 07:00:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMiX2h0dHBzOi8vYXBuZXdzLmNvbS9hcnRpY2xlL3J1c3NpYS11a3JhaW5lLXdhci1jcmltZWEtcGVuaW5zdWxhLWRmZjM0ODRkYTgyNGUxMWFmYzkyYzgzZWNmMTlmNzFi0gEA?oc=5&hl=en-US&gl=US&ceid=US:en', 'publisher': {'href': 'https://apnews.com', 'title': 'The Associated Press'}}

# %%
# Convert to DataFrame
df = pd.DataFrame(searchednews)
df.tail(20)
# Out:
#                                                 title  \
# 31   Ukraine war causes birth rate to slump - BBC.com
# 32  Ukraine's grain deal halt and how to truly hel...
# 33  Letting Europe's Energy Crisis Go to Waste: Th...
# 34  Ukrainian counteroffensive’s slow going offers...
# 35  Russia-Ukraine war at a glance: what we know o...
# 36  Russia attacks more Ukrainian ports and grain ...
# 37  Ukraine's latest weapons in its war with Russi...
# 38  Russia targets Odesa port, angering Ukraine an...
# 39  Russia had time to prepare for Ukraine offensi...
# 40  Saudi Arabia and Turkey are emerging as the ne...
# 41           August 1, 2023 Russia-Ukraine news - CNN
# 42  Your task is to ensure that the world always s...
# 43  Amanda Kaulins '13 heading back to Poland-Ukra...
# 44  Ukraine war latest: More drones coming, Ukrain...
# 45  IMPRESS-U – an opportunity for Polish and Ukra...
# 46  BP profits drop after Russia-Ukraine war windf...
# 47  Hull photo exhibition of Ukraine war shows 'co...
# 48  The impact of war on Ukraine's residential car...
# 49  What is going on with the Ukrainian counteroff...
# 50  Ukraine and Italy win Human Rights and Nursing...
#
#                                           description  \
# 31    Ukraine war causes birth rate to slump  BBC.com
# 32  Ukraine's grain deal halt and how to truly hel...
# 33  Letting Europe's Energy Crisis Go to Waste: Th...
# 34  Ukrainian counteroffensive’s slow going offers...
# 35  Russia-Ukraine war at a glance: what we know o...
# 36  Russia attacks more Ukrainian ports and grain ...
# 37  Ukraine's latest weapons in its war with Russi...
# 38  Russia targets Odesa port, angering Ukraine an...
# 39  Russia had time to prepare for Ukraine offensi...
# 40  Saudi Arabia and Turkey are emerging as the ne...
# 41            August 1, 2023 Russia-Ukraine news  CNN
# 42  Your task is to ensure that the world always s...
# 43  Amanda Kaulins '13 heading back to Poland-Ukra...
# 39  {'href': 'https://www.businessinsider.com', 't...
# 40  {'href': 'https://www.cnbc.com', 'title': 'CNBC'}
# 41    {'href': 'https://www.cnn.com', 'title': 'CNN'}
# 42  {'href': 'https://www.president.gov.ua', 'titl...
# 43  {'href': 'https://www.smcvt.edu', 'title': 'Sa...
# 44  {'href': 'https://www.bbc.co.uk', 'title': 'BBC'}
# 45  {'href': 'https://www.ncn.gov.pl', 'title': 'n...
# 46  {'href': 'https://www.bbc.co.uk', 'title': 'BBC'}
# 47  {'href': 'https://www.bbc.co.uk', 'title': 'BBC'}
# 48  {'href': 'https://www.bond.org.uk', 'title': '...
# 49  {'href': 'https://www.rte.ie', 'title': 'RTE.ie'}
# 50  {'href': 'https://www.brunel.ac.uk', 'title': ...

# %%
# Breaking publisher column
df = pd.concat([df.drop(['publisher'], axis=1), df['publisher'].apply(pd.Series)], axis=1)
df.head(5)
# Out:
#                                                title  \
# 0  Ukraine is 'extraordinary laboratory' for mili...
# 1  The Crimean Peninsula is both a playground and...
# 2  Russia strikes Ukraine's Danube port, driving ...
# 3  Ukraine is finally freeing itself from centuri...
# 4  ‘Nowhere to hide’: The question troubling Ukra...
#
#                                          description  \
# 0  Ukraine is 'extraordinary laboratory' for mili...
# 1  The Crimean Peninsula is both a playground and...
# 2  Russia strikes Ukraine's Danube port, driving ...
# 3  Ukraine is finally freeing itself from centuri...
# 4  ‘Nowhere to hide’: The question troubling Ukra...
#
#                   published date  \
# 0  Tue, 01 Aug 2023 07:00:00 GMT
# 1  Tue, 01 Aug 2023 07:00:00 GMT
# 2  Wed, 02 Aug 2023 07:00:00 GMT
# 3  Tue, 01 Aug 2023 07:00:00 GMT
# 4  Tue, 01 Aug 2023 07:00:00 GMT
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMicWh0d...
# 1  https://news.google.com/rss/articles/CBMiX2h0d...
# 2  https://news.google.com/rss/articles/CBMia2h0d...
# 3  https://news.google.com/rss/articles/CBMie2h0d...
# 4  https://news.google.com/rss/articles/CBMiYWh0d...
#
#                               href                 title
# 0         https://defensescoop.com          DefenseScoop
# 1               https://apnews.com  The Associated Press
# 2          https://www.reuters.com               Reuters
# 3  https://www.atlanticcouncil.org      Atlantic Council
# 4              https://www.cnn.com                   CNN

# %%
# Cleaning dataframe
df['media'] = df['title'].iloc[:,-1]
df = df[['published date','media','url']]
df.head(20)
# Out:
#                    published date                     media  \
# 0   Tue, 01 Aug 2023 07:00:00 GMT              DefenseScoop
# 1   Tue, 01 Aug 2023 07:00:00 GMT      The Associated Press
# 2   Wed, 02 Aug 2023 07:00:00 GMT                   Reuters
# 3   Tue, 01 Aug 2023 07:00:00 GMT          Atlantic Council
# 4   Tue, 01 Aug 2023 07:00:00 GMT                       CNN
# 5   Tue, 01 Aug 2023 07:00:00 GMT        Al Jazeera English
# 6   Tue, 01 Aug 2023 07:00:00 GMT         Idaho Capital Sun
# 7   Wed, 02 Aug 2023 07:00:00 GMT        The New York Times
# 8   Tue, 01 Aug 2023 07:00:00 GMT   The Wall Street Journal
# 9   Tue, 01 Aug 2023 07:00:00 GMT       The Washington Post
# 10  Tue, 01 Aug 2023 07:00:00 GMT           POLITICO Europe
# 11  Tue, 01 Aug 2023 07:00:00 GMT       Scientific American
# 12  Wed, 02 Aug 2023 07:00:00 GMT      The Associated Press
# 13  Wed, 02 Aug 2023 07:00:00 GMT        Al Jazeera English
# 14  Tue, 01 Aug 2023 07:00:00 GMT                   Reuters
# 15  Tue, 01 Aug 2023 07:00:00 GMT      The Associated Press
# 16  Wed, 02 Aug 2023 07:00:00 GMT                   Reuters
# 17  Wed, 02 Aug 2023 07:00:00 GMT        Al Jazeera English
# 18  Wed, 02 Aug 2023 07:00:00 GMT   The Wall Street Journal
# 19  Wed, 02 Aug 2023 07:00:00 GMT  Foreign Affairs Magazine
#
#                                                   url
# 0   https://news.google.com/rss/articles/CBMicWh0d...
# 1   https://news.google.com/rss/articles/CBMiX2h0d...
# 2   https://news.google.com/rss/articles/CBMia2h0d...
# 3   https://news.google.com/rss/articles/CBMie2h0d...
# 4   https://news.google.com/rss/articles/CBMiYWh0d...
# 5   https://news.google.com/rss/articles/CBMiVWh0d...
# 6   https://news.google.com/rss/articles/CBMiX2h0d...
# 7   https://news.google.com/rss/articles/CBMiXGh0d...
# 8   https://news.google.com/rss/articles/CBMibWh0d...
# 9   https://news.google.com/rss/articles/CBMiVmh0d...
# 10  https://news.google.com/rss/articles/CBMiUmh0d...
# 11  https://news.google.com/rss/articles/CBMidGh0d...
# 12  https://news.google.com/rss/articles/CBMiZ2h0d...
# 13  https://news.google.com/rss/articles/CBMiVWh0d...
# 14  https://news.google.com/rss/articles/CBMieWh0d...
# 15  https://news.google.com/rss/articles/CBMiaWh0d...
# 16  https://news.google.com/rss/articles/CBMiYGh0d...
# 17  https://news.google.com/rss/articles/CBMiY2h0d...
# 18  https://news.google.com/rss/articles/CBMiV2h0d...
# 19  https://news.google.com/rss/articles/CBMiTWh0d...

# %%
# Get the full article extracting and parsing the article and drop the links that give problems

list = []

for ind in tqdm(df.index, colour="green", desc="Extracting articles from the internet"):
  dict = {}
  
  try:
    article = googlenews.get_full_article(searchednews[ind]['url'])
    article.download()
    article.parse()
    article.nlp()
    dict['Date'] = df['published date'][ind]
    dict['Media'] = df['media'][ind]
    dict['Title'] = article.title
    dict['Article'] = article.text
    dict['Summary'] = article.summary
    list.append(dict)
  except Exception:
    df.drop([ind],axis=0,inplace=True)
# Out:
# Extracting articles from the internet:   0%|          | 0/51 [00:00<?, ?it/s]
# Extracting articles from the internet:  47%|████▋     | 24/51 [00:00<00:00, 122.39it/s]
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
# Extracting articles from the internet: 100%|██████████| 51/51 [00:00<00:00, 173.46it/s]
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.
#
# get_full_article() requires the `newspaper3k` library.
# You can install it by running `pip3 install newspaper3k` in your shell.

# %%
# Create the news dataframe with full articles
news_df = pd.DataFrame(list)
news_df.head(20)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Checking one article
news_df.iloc[7]['Article']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Checking one article
# ----> 2 news_df.iloc[7]['Article']
#
# File ~/Documents/Udemy ML-AI/Web-Scrapping/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Documents/Udemy ML-AI/Web-Scrapping/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/Documents/Udemy ML-AI/Web-Scrapping/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
