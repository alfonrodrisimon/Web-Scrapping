# %%
# Import libraries
# GoogleNews Documentation : https://pypi.org/project/gnews/
from gnews import GNews
import pandas as pd
import nltk  # NLP library
import warnings
from datetime import date

warnings.filterwarnings('ignore')

# %%
# This tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alfonso/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Initializing
googlenews = GNews()

# %%
# Settings
today = date.today()
googlenews = GNews(start_date=(2023, 1, 1), end_date=(today.year,today.month,today.day))

# %%
# Search 
topic = "Gold"
searchednews = googlenews.get_news(topic)
print(f"Articles found:", len(searchednews))
# Out:
# Articles found: 97

# %%
# Results
print(searchednews[1])
# Out:
# {'title': 'Gold slips from all-time peak on profit taking, firmer dollar - Reuters', 'description': 'Gold slips from all-time peak on profit taking, firmer dollar  Reuters', 'published date': 'Fri, 19 Jul 2024 07:00:00 GMT', 'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en', 'publisher': {'href': 'https://www.reuters.com', 'title': 'Reuters'}}

# %%
# Convert to DataFrame
df = pd.DataFrame(searchednews)
df.tail(20)
# Out:
#                                                 title  \
# 77  MIT physicists turn pencil lead into “gold” - ...
# 78  Gold drops more than 2% to one-week low as Mid...
# 79  Gold rebounds from lows after weak US jobs ope...
# 80  Gold prices dip after record highs on profit t...
# 81  Alphabet Soup: NASA’s GOLD Finds Surprising C,...
# 82  Gold rises on softer dollar as focus shifts to...
# 83  Gold gains on dollar retreat, focus now on US ...
# 84  Gold shines amid geopolitical uncertainties - ...
# 85  China Is Buying Gold Like There’s No Tomorrow ...
# 86  Gold drops from near-record level as US jobs d...
# 87  Gold prices hit a record high above $2,200 aft...
# 88  NASA to Take Part in Hidden Figures Congressio...
# 89  Will gold's price hit $3,000 per ounce? Expert...
# 90  Direct visualization of ligands on gold nanopa...
# 91  Gold retreats as dimming rate cut expectations...
# 92  Gold has broken through the $2,300 level, and ...
# 93  Have gold prices peaked for 2024? Here's what ...
# 94  What will happen to the price of gold if infla...
# 95  Gold prices are surging: Where to buy 1-ounce ...
# 96  Gold nugget formation from earthquake-induced ...
#
#                                           description  \
# 77  MIT physicists turn pencil lead into “gold”  M...
# 78  Gold drops more than 2% to one-week low as Mid...
# 79  Gold rebounds from lows after weak US jobs ope...
# 80  Gold prices dip after record highs on profit t...
# 81  Alphabet Soup: NASA’s GOLD Finds Surprising C,...
# 82  Gold rises on softer dollar as focus shifts to...
# 83  Gold gains on dollar retreat, focus now on US ...
# 84  Gold shines amid geopolitical uncertainties  W...
# 85  China Is Buying Gold Like There’s No Tomorrow ...
# 86  Gold drops from near-record level as US jobs d...
# 87  Gold prices hit a record high above $2,200 aft...
# 88  NASA to Take Part in Hidden Figures Congressio...
# 89  Will gold's price hit $3,000 per ounce? Expert...
# 90  Direct visualization of ligands on gold nanopa...
# 82  {'href': 'https://www.reuters.com', 'title': '...
# 83  {'href': 'https://www.reuters.com', 'title': '...
# 84  {'href': 'https://blogs.worldbank.org', 'title...
# 85  {'href': 'https://www.nytimes.com', 'title': '...
# 86  {'href': 'https://www.reuters.com', 'title': '...
# 87  {'href': 'https://fortune.com', 'title': 'Fort...
# 88  {'href': 'https://www.nasa.gov', 'title': 'NASA'}
# 89  {'href': 'https://www.cbsnews.com', 'title': '...
# 90  {'href': 'https://www.nature.com', 'title': 'N...
# 91  {'href': 'https://www.reuters.com', 'title': '...
# 92  {'href': 'https://www.cnbc.com', 'title': 'CNBC'}
# 93  {'href': 'https://www.cbsnews.com', 'title': '...
# 94  {'href': 'https://www.cbsnews.com', 'title': '...
# 95  {'href': 'https://www.cbsnews.com', 'title': '...
# 96  {'href': 'https://www.nature.com', 'title': 'N...

# %%
# Breaking publisher column
df['Title'] = df['title']
df = pd.concat([df.drop(['publisher'], axis=1), df['publisher'].apply(pd.Series)], axis=1)
df.head(5)
# Out:
#                                                title  \
# 0  Dr. Henry J. Gold Obituary 2024 - Goldsteins F...
# 1  Gold slips from all-time peak on profit taking...
# 2  Gold prices forecast to climb to record high -...
# 3          Why gold prices are at record highs - CNN
# 4    Velma Gold Obituary 2024 - Chauvin Funeral Home
#
#                                          description  \
# 0  Dr. Henry J. Gold Obituary 2024  Goldsteins Fu...
# 1  Gold slips from all-time peak on profit taking...
# 2  Gold prices forecast to climb to record high  ...
# 3           Why gold prices are at record highs  CNN
# 4     Velma Gold Obituary 2024  Chauvin Funeral Home
#
#                   published date  \
# 0  Sun, 14 Apr 2024 07:00:00 GMT
# 1  Fri, 19 Jul 2024 07:00:00 GMT
# 2  Thu, 12 Sep 2024 17:42:53 GMT
# 3  Tue, 09 Apr 2024 07:00:00 GMT
# 4  Sun, 18 Feb 2024 08:00:00 GMT
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMiXkFVX...
# 1  https://news.google.com/rss/articles/CBMisAFBV...
# 2  https://news.google.com/rss/articles/CBMilgFBV...
# 3  https://news.google.com/rss/articles/CBMif0FVX...
# 4  https://news.google.com/rss/articles/CBMiZ0FVX...
#
#                                                Title  \
# 0  Dr. Henry J. Gold Obituary 2024 - Goldsteins F...
# 1  Gold slips from all-time peak on profit taking...
# 2  Gold prices forecast to climb to record high -...
# 3          Why gold prices are at record highs - CNN
# 4    Velma Gold Obituary 2024 - Chauvin Funeral Home
#
#                                   href                 title
# 0  https://obits.goldsteinsfuneral.com    Goldsteins Funeral
# 1              https://www.reuters.com               Reuters
# 2         https://www.goldmansachs.com      goldmansachs.com
# 3                  https://www.cnn.com                   CNN
# 4   https://www.chauvinfuneralhome.com  Chauvin Funeral Home

# %%
# Cleaning dataframe
df['Media'] = df['title'].iloc[:,-1]
df['url'] = df['url'].apply(lambda x: '=HYPERLINK("'+ x +'")')
news_df = df[['published date','Media','Title','url']]
news_df.head(20)
# Out:
#                    published date                      Media  \
# 0   Sun, 14 Apr 2024 07:00:00 GMT         Goldsteins Funeral
# 1   Fri, 19 Jul 2024 07:00:00 GMT                    Reuters
# 2   Thu, 12 Sep 2024 17:42:53 GMT           goldmansachs.com
# 3   Tue, 09 Apr 2024 07:00:00 GMT                        CNN
# 4   Sun, 18 Feb 2024 08:00:00 GMT       Chauvin Funeral Home
# 5   Thu, 29 Feb 2024 13:28:47 GMT        philadelphiafed.org
# 6   Thu, 02 Feb 2023 08:00:00 GMT                 Earthworks
# 7   Fri, 17 May 2024 07:00:00 GMT                PR Newswire
# 8   Thu, 11 Jul 2024 07:00:00 GMT  Georgian Court University
# 9   Tue, 16 Jul 2024 07:00:00 GMT                MarketWatch
# 10  Sat, 22 Apr 2023 07:00:00 GMT         The New York Times
# 11  Thu, 21 Mar 2024 05:01:03 GMT     JP Morgan Private Bank
# 12  Fri, 13 Sep 2024 11:35:00 GMT                    Reuters
# 13  Fri, 19 Apr 2024 07:00:00 GMT                    Reuters
# 14  Tue, 20 Aug 2024 07:00:00 GMT                    Reuters
# 15  Fri, 05 Jul 2024 07:00:00 GMT                    Reuters
# 16  Thu, 12 Sep 2024 18:23:00 GMT                    Reuters
# 17  Tue, 02 Apr 2024 07:00:00 GMT                    Reuters
# 18  Mon, 09 Sep 2024 18:07:00 GMT                    Reuters
# 19  Mon, 04 Mar 2024 08:00:00 GMT                    Reuters
#
#                                                 Title  \
# 0   Dr. Henry J. Gold Obituary 2024 - Goldsteins F...
# 1   Gold slips from all-time peak on profit taking...
# 2   Gold prices forecast to climb to record high -...
# 3           Why gold prices are at record highs - CNN
# 4     Velma Gold Obituary 2024 - Chauvin Funeral Home
# 5   Price-Level Determination Under the Gold Stand...
# 6   Surviving Next to One of the World’s Largest G...
# 7   NEW GOLD COMPLETES US$173 MILLION BOUGHT DEAL ...
# 8   Blue & Gold Days for Accepted Students - Georg...
# 9   Why gold prices look likely to smash more reco...
# 10  Eureka! After California’s Heavy Rains, Gold S...
# 11  Is it a golden era for gold? - JP Morgan Priva...
# 12  Gold bulls set sights on previously dismissed ...
# 13  Gold on track for weekly rise as Middle East r...
# 14  Gold extends record rally on dollar weakness, ...
# 15  Gold prices rise to over one-month high after ...
# 16  Gold hits all-time high as Fed rate-cut hopes ...
# 17  Gold shatters new records as Mideast tensions ...
# 18  Gold prices steady with spotlight on US inflat...
# 19  Gold advances to three-month high on rising ra...
#
#                                                   url
# 0   =HYPERLINK("https://news.google.com/rss/articl...
# 1   =HYPERLINK("https://news.google.com/rss/articl...
# 2   =HYPERLINK("https://news.google.com/rss/articl...
# 3   =HYPERLINK("https://news.google.com/rss/articl...
# 4   =HYPERLINK("https://news.google.com/rss/articl...
# 5   =HYPERLINK("https://news.google.com/rss/articl...
# 6   =HYPERLINK("https://news.google.com/rss/articl...
# 7   =HYPERLINK("https://news.google.com/rss/articl...
# 8   =HYPERLINK("https://news.google.com/rss/articl...
# 9   =HYPERLINK("https://news.google.com/rss/articl...
# 10  =HYPERLINK("https://news.google.com/rss/articl...
# 11  =HYPERLINK("https://news.google.com/rss/articl...
# 12  =HYPERLINK("https://news.google.com/rss/articl...
# 13  =HYPERLINK("https://news.google.com/rss/articl...
# 14  =HYPERLINK("https://news.google.com/rss/articl...
# 15  =HYPERLINK("https://news.google.com/rss/articl...
# 16  =HYPERLINK("https://news.google.com/rss/articl...
# 17  =HYPERLINK("https://news.google.com/rss/articl...
# 18  =HYPERLINK("https://news.google.com/rss/articl...
# 19  =HYPERLINK("https://news.google.com/rss/articl...

# %%
# Convert the column to datetime
news_df['Date'] = pd.to_datetime(news_df['published date'])
#Sort values and reset index
news_df = news_df.sort_values(by='Date')
news_df.reset_index(drop=True,inplace=True)
#Change column date format
news_df['Date'] = news_df['Date'].dt.strftime('%d/%m/%Y')
news_df = news_df[['Date','Media','Title','url']]
news_df
# Out:
#           Date               Media  \
# 0   02/02/2023          Earthworks
# 1   07/04/2023         Roger Ebert
# 2   22/04/2023  The New York Times
# 3   31/10/2023  World Gold Council
# 4   14/11/2023            MIT News
# ..         ...                 ...
# 92  10/09/2024             Reuters
# 93  12/09/2024    goldmansachs.com
# 94  12/09/2024             Reuters
# 95  13/09/2024             Reuters
# 96  13/09/2024             Reuters
#
#                                                 Title  \
# 0   Surviving Next to One of the World’s Largest G...
# 1   Country Gold movie review & film summary (2023...
# 2   Eureka! After California’s Heavy Rains, Gold S...
# 3     Gold Demand Trends Q3 2023 - World Gold Council
# 4   MIT physicists turn pencil lead into “gold” - ...
# ..                                                ...
# 92  Gold holds firm above $2,500 level as US infla...
# 93  Gold prices forecast to climb to record high -...
# 94  Gold hits all-time high as Fed rate-cut hopes ...
# 95  Gold bulls set sights on previously dismissed ...
# 96  Prospect of steeper Fed cuts boosts stocks, dr...
#
#                                                   url
# 0   =HYPERLINK("https://news.google.com/rss/articl...
# 1   =HYPERLINK("https://news.google.com/rss/articl...
# 2   =HYPERLINK("https://news.google.com/rss/articl...
# 3   =HYPERLINK("https://news.google.com/rss/articl...
# 4   =HYPERLINK("https://news.google.com/rss/articl...
# ..                                                ...
# 92  =HYPERLINK("https://news.google.com/rss/articl...
# 93  =HYPERLINK("https://news.google.com/rss/articl...
# 94  =HYPERLINK("https://news.google.com/rss/articl...
# 95  =HYPERLINK("https://news.google.com/rss/articl...
# 96  =HYPERLINK("https://news.google.com/rss/articl...
#
# [97 rows x 4 columns]

# %%
#Save in a document
topic = topic.replace(" ","_")
news_df.to_csv(f"./output/{topic}.csv")
