# %%
# Import libraries
# GoogleNews Documentation : https://pypi.org/project/gnews/
from gnews import GNews
import pandas as pd
import nltk  # NLP library
import warnings

warnings.filterwarnings('ignore')

# %%
# This tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alfonso/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Initializing
googlenews = GNews()

# %%
# Settings
googlenews = GNews(start_date=(2023, 1, 1), end_date=(2024, 5, 17))

# %%
# Search 
topic = "Audax Renovables"
searchednews = googlenews.get_news(topic)
print(f"Articles found:", len(searchednews))
# Out:
# Articles found: 100

# %%
# Results
print(searchednews[1])
# Out:
# {'title': "Spain's Audax reports shining fin results for 2023, profit up 304% - Renewables Now", 'description': "Spain's Audax reports shining fin results for 2023, profit up 304%  Renewables Now", 'published date': 'Fri, 08 Mar 2024 08:00:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMiZmh0dHBzOi8vcmVuZXdhYmxlc25vdy5jb20vbmV3cy9zcGFpbnMtYXVkYXgtcmVwb3J0cy1zaGluaW5nLWZpbi1yZXN1bHRzLWZvci0yMDIzLXByb2ZpdC11cC0zMDQtODUwOTc4L9IBAA?oc=5&hl=en-US&gl=US&ceid=US:en', 'publisher': {'href': 'https://renewablesnow.com', 'title': 'Renewables Now'}}

# %%
# Convert to DataFrame
df = pd.DataFrame(searchednews)
df.tail(20)
# Out:
#                                                 title  \
# 80  Audax duplica su EBITDA a septiembre de 2023, ...
# 81  Audax Solar sortea las alegaciones de Villena ...
# 82  Audax acelera para firmar un socio estratégico...
# 83  Audax Renovables ataca resistencias clave del ...
# 84  Rechazada planta de 700 MW de Audax Energy en ...
# 85  Noticias del Mercado Continuo Audax Renovables...
# 86  Audax sale de pérdidas y dispara un 56% sus in...
# 87  Audax multiplica por cuatro su beneficio en el...
# 88  Audax Renovables ficha en la cosmética y le ro...
# 89  CEOE y Audax renuevan su convenio de colaborac...
# 90  Audax deja atrás los números rojos y gana 7,8 ...
# 91  Plan Estratégico de Audax, liderar la transici...
# 92  ADX Energía se adjudica el suministro eléctric...
# 93  Audax Renovables se adjudica el contrato de su...
# 94  Renovables. Vencedores y vencidos de la burbuj...
# 95  Audax aumenta su EBITDA un 78%, superando los ...
# 96  El 'boom verde' dispara el negocio de Audax, S...
# 97  Las firmas de renovables a las que 'echar el l...
# 98  El sector renovable brilla en el Mercado Conti...
# 99  Audax Renovables bate todos los registros: gan...
#
#                                           description  \
# 80  Audax duplica su EBITDA a septiembre de 2023, ...
# 81  Audax Solar sortea las alegaciones de Villena ...
# 82  Audax acelera para firmar un socio estratégico...
# 83  Audax Renovables ataca resistencias clave del ...
# 84  Rechazada planta de 700 MW de Audax Energy en ...
# 85  Noticias del Mercado Continuo Audax Renovables...
# 86  Audax sale de pérdidas y dispara un 56% sus in...
# 87  Audax multiplica por cuatro su beneficio en el...
# 88  Audax Renovables ficha en la cosmética y le ro...
# 89  CEOE y Audax renuevan su convenio de colaborac...
# 82  {'href': 'https://www.lainformacion.com', 'tit...
# 83  {'href': 'https://www.bolsamania.com', 'title'...
# 84  {'href': 'https://www.pv-magazine.es', 'title'...
# 85  {'href': 'https://consensodelmercado.com', 'ti...
# 86  {'href': 'https://www.eleconomista.es', 'title...
# 87  {'href': 'https://www.elnacional.cat', 'title'...
# 88  {'href': 'https://www.lainformacion.com', 'tit...
# 89  {'href': 'https://nuevaalcarria.com', 'title':...
# 90  {'href': 'https://www.expansion.com', 'title':...
# 91  {'href': 'https://www.estrategiasdeinversion.c...
# 92  {'href': 'https://www.granadahoy.com', 'title'...
# 93  {'href': 'https://www.moncloa.com', 'title': '...
# 94  {'href': 'https://www.hispanidad.com', 'title'...
# 95  {'href': 'https://www.estrategiasdeinversion.c...
# 96  {'href': 'https://www.expansion.com', 'title':...
# 97  {'href': 'https://www.eleconomista.es', 'title...
# 98  {'href': 'https://www.estrategiasdeinversion.c...
# 99  {'href': 'https://cronicaglobal.elespanol.com'...

# %%
# Breaking publisher column
df['Title'] = df['title']
df = pd.concat([df.drop(['publisher'], axis=1), df['publisher'].apply(pd.Series)], axis=1)
df.head(5)
# Out:
#                                                title  \
# 0  A Piece Of The Puzzle Missing From Audax Renov...
# 1  Spain's Audax reports shining fin results for ...
# 2  Despite delivering investors losses of 50% ove...
# 3  Citadel honcho boosts stake in Spain's Audax t...
# 4  Insiders were the biggest winners as Audax Ren...
#
#                                          description  \
# 0  A Piece Of The Puzzle Missing From Audax Renov...
# 1  Spain's Audax reports shining fin results for ...
# 2  Despite delivering investors losses of 50% ove...
# 3  Citadel honcho boosts stake in Spain's Audax t...
# 4  Insiders were the biggest winners as Audax Ren...
#
#                   published date  \
# 0  Tue, 02 Apr 2024 07:00:00 GMT
# 1  Fri, 08 Mar 2024 08:00:00 GMT
# 2  Thu, 25 Jan 2024 08:00:00 GMT
# 3  Mon, 18 Mar 2024 07:00:00 GMT
# 4  Fri, 19 Apr 2024 07:00:00 GMT
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMiiwFod...
# 1  https://news.google.com/rss/articles/CBMiZmh0d...
# 2  https://news.google.com/rss/articles/CBMijQFod...
# 3  https://news.google.com/rss/articles/CBMiXGh0d...
# 4  https://news.google.com/rss/articles/CBMiiwFod...
#
#                                                Title  \
# 0  A Piece Of The Puzzle Missing From Audax Renov...
# 1  Spain's Audax reports shining fin results for ...
# 2  Despite delivering investors losses of 50% ove...
# 3  Citadel honcho boosts stake in Spain's Audax t...
# 4  Insiders were the biggest winners as Audax Ren...
#
#                         href           title
# 0      https://simplywall.st  Simply Wall St
# 1  https://renewablesnow.com  Renewables Now
# 2      https://simplywall.st  Simply Wall St
# 3  https://renewablesnow.com  Renewables Now
# 4      https://simplywall.st  Simply Wall St

# %%
# Cleaning dataframe
df['Media'] = df['title'].iloc[:,-1]
df['url'] = df['url'].apply(lambda x: '=HYPERLINK("'+ x +'")')
news_df = df[['published date','Media','Title','url']]
news_df.head(20)
# Out:
#                    published date                       Media  \
# 0   Tue, 02 Apr 2024 07:00:00 GMT              Simply Wall St
# 1   Fri, 08 Mar 2024 08:00:00 GMT              Renewables Now
# 2   Thu, 25 Jan 2024 08:00:00 GMT              Simply Wall St
# 3   Mon, 18 Mar 2024 07:00:00 GMT              Renewables Now
# 4   Fri, 19 Apr 2024 07:00:00 GMT              Simply Wall St
# 5   Thu, 21 Dec 2023 08:00:00 GMT              Renewables Now
# 6   Thu, 09 May 2024 05:35:23 GMT              Simply Wall St
# 7   Wed, 03 Apr 2024 07:00:00 GMT              Renewables Now
# 8   Thu, 18 Jan 2024 08:00:00 GMT                       Yahoo
# 9   Thu, 18 Jan 2024 08:00:00 GMT  elperiodicodelaenergia.com
# 10  Tue, 30 Apr 2024 07:00:00 GMT              Renewables Now
# 11  Mon, 13 Nov 2023 08:00:00 GMT                  Cinco Días
# 12  Wed, 28 Feb 2024 08:00:00 GMT                       Yahoo
# 13  Fri, 15 Mar 2024 07:00:00 GMT               La Vanguardia
# 14  Wed, 27 Sep 2023 07:00:00 GMT              Renewables Now
# 15  Sun, 31 Mar 2024 07:00:00 GMT  elperiodicodelaenergia.com
# 16  Thu, 04 Apr 2024 07:00:00 GMT                       Yahoo
# 17  Thu, 28 Sep 2023 07:00:00 GMT                       Yahoo
# 18  Tue, 07 Nov 2023 08:00:00 GMT                       Yahoo
# 19  Fri, 12 Apr 2024 07:00:00 GMT                       Yahoo
#
#                                                 Title  \
# 0   A Piece Of The Puzzle Missing From Audax Renov...
# 1   Spain's Audax reports shining fin results for ...
# 2   Despite delivering investors losses of 50% ove...
# 3   Citadel honcho boosts stake in Spain's Audax t...
# 4   Insiders were the biggest winners as Audax Ren...
# 5   Spain's Audax starts building 57.5-MW solar fa...
# 6   Audax Renovables' (BME:ADX) Returns On Capital...
# 7   Audax bags public contract for renewable power...
# 8   Audax reduce su deuda bruta en 41,4 millones d...
# 9   El mundo agregará energías renovables en cinco...
# 10  Audax wins bid to power Picasso's birthplace a...
# 11  Audax Renovables se dispara un 9% en Bolsa tra...
# 12  Audax aumenta su EBITDA un 78%, superando los ...
# 13  El multimillonario Kenneth Griffin se refuerza...
# 14  Panama wind farm company issues USD-200m green...
# 15  Expertos resaltan el potencial de crecimiento ...
# 16  El sector renovable brilla en el Mercado Conti...
# 17  Audax Renovables multiplica por más de tres el...
# 18  Audax: "Con nuestro Plan de Sostenibilidad, bu...
# 19  Audax sube un 9,5% en el Continuo tras anuncia...
#
#                                                   url
# 0   =HYPERLINK("https://news.google.com/rss/articl...
# 1   =HYPERLINK("https://news.google.com/rss/articl...
# 2   =HYPERLINK("https://news.google.com/rss/articl...
# 3   =HYPERLINK("https://news.google.com/rss/articl...
# 4   =HYPERLINK("https://news.google.com/rss/articl...
# 5   =HYPERLINK("https://news.google.com/rss/articl...
# 6   =HYPERLINK("https://news.google.com/rss/articl...
# 7   =HYPERLINK("https://news.google.com/rss/articl...
# 8   =HYPERLINK("https://news.google.com/rss/articl...
# 9   =HYPERLINK("https://news.google.com/rss/articl...
# 10  =HYPERLINK("https://news.google.com/rss/articl...
# 11  =HYPERLINK("https://news.google.com/rss/articl...
# 12  =HYPERLINK("https://news.google.com/rss/articl...
# 13  =HYPERLINK("https://news.google.com/rss/articl...
# 14  =HYPERLINK("https://news.google.com/rss/articl...
# 15  =HYPERLINK("https://news.google.com/rss/articl...
# 16  =HYPERLINK("https://news.google.com/rss/articl...
# 17  =HYPERLINK("https://news.google.com/rss/articl...
# 18  =HYPERLINK("https://news.google.com/rss/articl...
# 19  =HYPERLINK("https://news.google.com/rss/articl...

# %%
# Convert the column to datetime
news_df['Date'] = pd.to_datetime(news_df['published date'])
#Sort values and reset index
news_df = news_df.sort_values(by='Date')
news_df.reset_index(drop=True,inplace=True)
#Change column date format
news_df['Date'] = news_df['Date'].dt.strftime('%d/%m/%Y')
news_df = news_df[['Date','Media','Title','url']]
news_df
# Out:
#           Date               Media  \
# 0   01/02/2023      Hispanidad.com
# 1   10/02/2023  pv magazine España
# 2   22/02/2023       Forbes España
# 3   27/02/2023       UAE Expansion
# 4   27/02/2023        elEconomista
# ..         ...                 ...
# 95  15/05/2024          Bolsamania
# 96  15/05/2024        elEconomista
# 97  15/05/2024        El Periódico
# 98  15/05/2024      Crónica Global
# 99  15/05/2024      Hispanidad.com
#
#                                                 Title  \
# 0   Audax Renovables y su principal accionista, Jo...
# 1   Rechazada planta de 700 MW de Audax Energy en ...
# 2   Audax Renovables suma 231 MWp con declaración ...
# 3   Audax deja atrás los números rojos y gana 7,8 ...
# 4   Audax sale de pérdidas y dispara un 56% sus in...
# ..                                                ...
# 95  Economía/Empresas.- Audax Renovables dispara s...
# 96  Audax Renovables gana 17 millones en un primer...
# 97  Audax Renovables multiplica su beneficio hasta...
# 98  Audax Renovables bate todos los registros: gan...
# 99  José Elías no descorcha el cava: los ingresos ...
#
#                                                   url
# 0   =HYPERLINK("https://news.google.com/rss/articl...
# 1   =HYPERLINK("https://news.google.com/rss/articl...
# 2   =HYPERLINK("https://news.google.com/rss/articl...
# 3   =HYPERLINK("https://news.google.com/rss/articl...
# 4   =HYPERLINK("https://news.google.com/rss/articl...
# ..                                                ...
# 95  =HYPERLINK("https://news.google.com/rss/articl...
# 96  =HYPERLINK("https://news.google.com/rss/articl...
# 97  =HYPERLINK("https://news.google.com/rss/articl...
# 98  =HYPERLINK("https://news.google.com/rss/articl...
# 99  =HYPERLINK("https://news.google.com/rss/articl...
#
# [100 rows x 4 columns]

# %%
#Save in a document
topic = topic.replace(" ","_")
news_df.to_csv(f"./output/{topic}.csv")
